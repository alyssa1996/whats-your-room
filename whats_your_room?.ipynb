# %% [markdown]
# <a href="https://colab.research.google.com/github/alyssa1996/whats-your-room/blob/main/whats_your_room%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://docs.google.com/spreadsheets/u/1/d/1f73hTHz50lqkuXD3KLy0Al7yUK80JSqrC0iUH3Xakwg/htmlview#"
dfs = pd.read_html(url,encoding="UTF-8")

# %%
room_escape = dfs[0]
escape_data = pd.DataFrame(data=room_escape,index=room_escape.index[1:],columns=room_escape.columns[1:10])

# %%
escape_data =  escape_data.rename(columns=escape_data.iloc[0])
escape_data.drop(escape_data.index[0:2], inplace=True) #[5,6], axis=0, inplace=True
escape_data
# Out:
#         번호  지역         지점명   호점                    테마명 난이도     추천도  공포도  활동성
# 3    [287]  강남    방탈출, 단편선  NaN  사람들은 그것을 행복이라 부르기로 했다   7  (0)S++   ●0  NaN
# 4    [063]  부평      넥스트에디션  NaN       THISMAN Original  10   (1)S+  NaN   ●1
# 5    [062]  건대          솔버  2호점                 디어 마르시   9   (1)S+  NaN   ●1
# 6    [188]  강남        제로월드  NaN                     콜러   9   (1)S+   ●3   ●1
# 7    [303]  강남        제로월드  NaN                     제로   9   (1)S+   ●3   ●2
# ..     ...  ..         ...  ...                    ...  ..     ...  ...  ...
# 253  [268]  잠실        셜록홈즈  1호점                 산속의 여인   3    (a)X   ●1  NaN
# 254  [278]  잠실  한국 방탈출 교육원  NaN              방탈출 능력 시험  11    Misc   ●0   ●2
# 255  [101]  잠실        마스터키  NaN        블랙룸 : 쉽게 만들어진 방  10    Misc  NaN  NaN
# 256  [198]  강남     도어이스케이프   레드                     유전  10    Misc   ●1  NaN
# 257  [265]  건대     트루이스케이프  2호점                 광복절 특사  10    Misc  NaN   ●1
#
# [255 rows x 9 columns]
